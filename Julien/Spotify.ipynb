# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
import pandas as pd

# %%
DEBUG_PROMPT = False

# %%
token = spotipy.util.prompt_for_user_token('Julien Salomon',
                           client_id='3f0268c00c604e70aace4982367723c7',
                           client_secret='c9a4a4f2699642c795cb82595c2c8035',
                            redirect_uri='http://localhost:8888')

# %%
spotify = spotipy.Spotify(auth=token)
spotify.trace = False # turn on tracing
spotify.trace_out = False # turn on trace out

# %%
def print_list(lis, tab=0):
    tabs = ''
    for i in range(tab):
        tabs += '\t'
    print(tabs + 'list_length: ' + str(len(lis)))
    for val in lis:
        if isinstance(val, dict):
            print_dict(val, tab=tab)
        elif isinstance(val, list):
            if len(val) <= 50 or DEBUG_PROMPT:
                print_list(val, tab=tab + 1)
        else:
            print(tabs + val)
            
def print_dict(dico, tab=0):
    tabs = ''
    for i in range(tab):
        tabs += '\t'
    for item, value in dico.items():
        if isinstance(value, dict):
            print(tabs + item + ':')
            print_dict(value, tab=tab+1)
        elif isinstance(value, list):
            print(tabs + item + ':')
            print_list(value, tab=tab + 1)
        else:
            print(tabs + item + ' : ' + str(value))

# %%
def print_result(res, info=None):
    if info:
        print(info)
    if isinstance(res, dict):
        print_dict(res)
    elif isinstance(res, list):
        print_list(res)
    else:
        print(res)

# %%
def get_artist(artist_name):
    results = spotify.search(artist_name, type='artist')['artists']['items']
    results.sort(key=lambda artist: artist['popularity'], reverse=True)
    top_result = results[0]
    if DEBUG_PROMPT:
        print_result(top_result, info='Artist')
    return top_result

# %%
def get_albums_tracks(albums):
    all_tracks = []
    for uri in albums:
        tracks = spotify.album_tracks(uri)['items']
        for track in tracks:
            track['album_uri'] = uri
        all_tracks += tracks
    
    return pd.DataFrame(all_tracks)

# %%
def get_audio_features(tracks):
    features_list = [spotify.audio_features(track)[0] for track in tracks]
    features = pd.DataFrame(features_list)
    features['uri_track'] = features['uri']
    features = features.drop('duration_ms', axis=1).drop('uri', axis=1)
    if DEBUG_PROMPT:
        print(features.head())
    return features

# %%
mj_albums = spotify.artist_albums(get_artist('Michael Jackson')['uri'])['items']
mj_df = pd.DataFrame.from_dict(mj_albums)
mj_df.head()
# Out:
#   album_group album_type                                            artists  \
# 0       album      album  [{'external_urls': {'spotify': 'https://open.s...
# 1       album      album  [{'external_urls': {'spotify': 'https://open.s...
# 2       album      album  [{'external_urls': {'spotify': 'https://open.s...
# 3       album      album  [{'external_urls': {'spotify': 'https://open.s...
# 4       album      album  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  \
# 0  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 1  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 2  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 3  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 4  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/album/2X...
# 1  {'spotify': 'https://open.spotify.com/album/7p...
# 2  {'spotify': 'https://open.spotify.com/album/54...
# 3  {'spotify': 'https://open.spotify.com/album/0y...
# 4  {'spotify': 'https://open.spotify.com/album/52...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/albums/2X8UOIkZQdcz...  2X8UOIkZQdcz2Hi5Ynt2uk
# 1  https://api.spotify.com/v1/albums/7pomP86PUhoJ...  7pomP86PUhoJpY3fsC0WDQ
# 2  https://api.spotify.com/v1/albums/54WFfZzds26N...  54WFfZzds26NrwcmStfamd
# 3  https://api.spotify.com/v1/albums/0yYWeLqonFk1...  0yYWeLqonFk11pmb0RiMbP
# 4  https://api.spotify.com/v1/albums/52E4RP7XDzal...  52E4RP7XDzalpIrOgSTgiQ
#
#                                               images  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                                  name release_date release_date_precision  \
# 0                              Scream   2017-09-27                    day
# 1                              XSCAPE   2014-05-09                    day
# 2  XSCAPE - Track by Track Commentary   2014-05-09                    day
# 3                             Michael   2010-12-14                    day
# 4                          Invincible   2001-10-29                    day
#
#    total_tracks   type                                   uri
# 0            14  album  spotify:album:2X8UOIkZQdcz2Hi5Ynt2uk
# 1            17  album  spotify:album:7pomP86PUhoJpY3fsC0WDQ
# 2             8  album  spotify:album:54WFfZzds26NrwcmStfamd
# 3            10  album  spotify:album:0yYWeLqonFk11pmb0RiMbP
# 4            16  album  spotify:album:52E4RP7XDzalpIrOgSTgiQ

# %%
mj_tracks_df = get_albums_tracks(mj_df.uri.unique())
mj_tracks_df.head()
# Out:
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# 1  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# 2  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# 3  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# 4  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
#
#    duration_ms  explicit                                      external_urls  \
# 0       343413     False  {'spotify': 'https://open.spotify.com/track/2B...
# 1       358053     False  {'spotify': 'https://open.spotify.com/track/7a...
# 2       253373     False  {'spotify': 'https://open.spotify.com/track/0Q...
# 3       237760     False  {'spotify': 'https://open.spotify.com/track/6A...
# 4       280946     False  {'spotify': 'https://open.spotify.com/track/4F...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/2BU4dK1fu1CF...  2BU4dK1fu1CFLjTBz7ju7Q
# 1  https://api.spotify.com/v1/tracks/7azo4rpSUh8n...  7azo4rpSUh8nXgtonC6Pkq
# 2  https://api.spotify.com/v1/tracks/0QgsvILuE9VQ...  0QgsvILuE9VQiAVsLStD3W
# 3  https://api.spotify.com/v1/tracks/6A4Jc8npNo79...  6A4Jc8npNo79BOgsrPptLA
# 4  https://api.spotify.com/v1/tracks/4FC7GMnGwYeA...  4FC7GMnGwYeAjuvC83Srbs
#
#    is_local                                        name  \
# 0     False  This Place Hotel (a.k.a. Heartbreak Hotel)
# 1     False                                    Thriller
# 2     False                    Blood on the Dance Floor
# 3     False     Somebody's Watching Me - Single Version
# 4     False                 Dirty Diana - 2012 Remaster
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/f17429c3426b249c...             1  track
# 1  https://p.scdn.co/mp3-preview/9f288fba4d3380b1...             2  track
# 2  https://p.scdn.co/mp3-preview/6ef56a67f7da9122...             3  track
# 3  https://p.scdn.co/mp3-preview/c1245127fedad1ee...             4  track
# 4  https://p.scdn.co/mp3-preview/532affb8368ee2a5...             5  track
#
#                                     uri                             album_uri
# 0  spotify:track:2BU4dK1fu1CFLjTBz7ju7Q  spotify:album:2X8UOIkZQdcz2Hi5Ynt2uk
# 1  spotify:track:7azo4rpSUh8nXgtonC6Pkq  spotify:album:2X8UOIkZQdcz2Hi5Ynt2uk
# 2  spotify:track:0QgsvILuE9VQiAVsLStD3W  spotify:album:2X8UOIkZQdcz2Hi5Ynt2uk
# 3  spotify:track:6A4Jc8npNo79BOgsrPptLA  spotify:album:2X8UOIkZQdcz2Hi5Ynt2uk
# 4  spotify:track:4FC7GMnGwYeAjuvC83Srbs  spotify:album:2X8UOIkZQdcz2Hi5Ynt2uk

# %%
mj_df['album_uri'] = mj_df.uri
mj_df = tracks_df.join(mj_df.set_index('album_uri'), lsuffix='_track', rsuffix='_album', on='album_uri')
if DEBUG_PROMPT:
    print(mj_df.columns)
#mj_df = mj_df[['name_track', 'duration_ms', 'explicit', 'artists_track', 'track_number', 'disc_number', 'name_album', 'artists_album', 'total_tracks', 'uri_track', 'uri_album']]

# %%
#Add tracks for non-MJ albums

# %%
track_uris = mj_df.uri_track.unique()

# %%
features = get_audio_features(track_uris)
# Out:
# retrying after...6secs
# retrying after...6secs

# %%
mj_df = mj_df.join(features.set_index('uri_track'), on='uri_track')

# %%
mj_df.head()
# Out:
#                                        artists_track  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                              available_markets_track  disc_number  \
# 0  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# 1  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# 2  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# 3  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# 4  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
#
#    duration_ms  explicit                                external_urls_track  \
# 0       343413     False  {'spotify': 'https://open.spotify.com/track/2B...
# 1       358053     False  {'spotify': 'https://open.spotify.com/track/7a...
# 2       253373     False  {'spotify': 'https://open.spotify.com/track/0Q...
# 3       237760     False  {'spotify': 'https://open.spotify.com/track/6A...
# 4       280946     False  {'spotify': 'https://open.spotify.com/track/4F...
#
#                                           href_track                id_track  \
# 0  https://api.spotify.com/v1/tracks/2BU4dK1fu1CF...  2BU4dK1fu1CFLjTBz7ju7Q
# 1  https://api.spotify.com/v1/tracks/7azo4rpSUh8n...  7azo4rpSUh8nXgtonC6Pkq
# 2  https://api.spotify.com/v1/tracks/0QgsvILuE9VQ...  0QgsvILuE9VQiAVsLStD3W
# 3  https://api.spotify.com/v1/tracks/6A4Jc8npNo79...  6A4Jc8npNo79BOgsrPptLA
# 4  https://api.spotify.com/v1/tracks/4FC7GMnGwYeA...  4FC7GMnGwYeAjuvC83Srbs
#
#    is_local                                  name_track  ... acousticness  \
# 0     False  This Place Hotel (a.k.a. Heartbreak Hotel)  ...       0.2430
# 1     False                                    Thriller  ...       0.0816
# 2     False                    Blood on the Dance Floor  ...       0.0148
# 3     False     Somebody's Watching Me - Single Version  ...       0.0409
# 4     False                 Dirty Diana - 2012 Remaster  ...       0.1780
#
#    instrumentalness liveness valence    tempo            type  \
# 0          0.000142   0.1170   0.582   97.005  audio_features
# 1          0.000108   0.8470   0.721  118.421  audio_features
# 2          0.009780   0.0623   0.520  108.980  audio_features
# 3          0.000081   0.1320   0.804  124.091  audio_features
# 4          0.000401   0.3240   0.331  131.424  audio_features
#
#                        id                                         track_href  \
# 0  2BU4dK1fu1CFLjTBz7ju7Q  https://api.spotify.com/v1/tracks/2BU4dK1fu1CF...
# 1  7azo4rpSUh8nXgtonC6Pkq  https://api.spotify.com/v1/tracks/7azo4rpSUh8n...
# 2  0QgsvILuE9VQiAVsLStD3W  https://api.spotify.com/v1/tracks/0QgsvILuE9VQ...
# 3  6A4Jc8npNo79BOgsrPptLA  https://api.spotify.com/v1/tracks/6A4Jc8npNo79...
# 4  4FC7GMnGwYeAjuvC83Srbs  https://api.spotify.com/v1/tracks/4FC7GMnGwYeA...
#
#                                         analysis_url time_signature
# 0  https://api.spotify.com/v1/audio-analysis/2BU4...              4
# 1  https://api.spotify.com/v1/audio-analysis/7azo...              4
# 2  https://api.spotify.com/v1/audio-analysis/0Qgs...              4
# 3  https://api.spotify.com/v1/audio-analysis/6A4J...              4
# 4  https://api.spotify.com/v1/audio-analysis/4FC7...              4
#
# [5 rows x 45 columns]

# %%
mj_df['featuring'] = mj_df.artists_track.map(lambda l: len(l) > 1)
mj_df['artists_track_uri'] = mj_df.artists_track.map(lambda artist_list: [artist['uri'] for artist in artist_list])
mj_df['artists_track'] = mj_df.artists_track.map(lambda artist_list: [artist['name'] for artist in artist_list])

mj_df = mj_df[['name_track', 'duration_ms', 'explicit', 'artists_track', 'artists_track_uri', 'featuring', 'track_number', 'disc_number', 'name_album', 'artists_album', 'total_tracks', 'uri_track', 'uri_album', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']]

# %%
mj_df.to_pickle('mj_df.pickle')
