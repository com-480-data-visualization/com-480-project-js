# %%
import pandas as pd
import seaborn as sns

# %%
DATA_PATH = '../data/'

# %%
tracks_df = pd.read_pickle(DATA_PATH + 'michael_jackson_tracks.pickle')
analysis_df = pd.read_pickle(DATA_PATH + 'michael_jackson_tracks_analysis.pickle')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-532966a95e0e> in <module>
# ----> 1 tracks_df = pd.read_pickle(DATA_PATH + 'michael_jackson_tracks.pickle')
#       2 analysis_df = pd.read_pickle(DATA_PATH + 'michael_jackson_tracks_analysis.pickle')
#
# ~/Anaconda3/lib/python3.7/site-packages/pandas/io/pickle.py in read_pickle(path, compression)
#     143     """
#     144     path = _stringify_path(path)
# --> 145     f, fh = _get_handle(path, "rb", compression=compression, is_text=False)
#     146
#     147     # 1) try standard libary Pickle
#
# ~/Anaconda3/lib/python3.7/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     403         else:
#     404             # Binary mode
# --> 405             f = open(path_or_buf, mode)
#     406         handles.append(f)
#     407
#
# ...

# %%
tracks_df.head()
# Out:
#                                    name_track  duration_ms  explicit  \
# 0  This Place Hotel (a.k.a. Heartbreak Hotel)       343413     False
# 1                                    Thriller       358053     False
# 2                    Blood on the Dance Floor       253373     False
# 3     Somebody's Watching Me - Single Version       237760     False
# 4                 Dirty Diana - 2012 Remaster       280946     False
#
#        artists_track                        artists_track_uri  featuring  \
# 0     [The Jacksons]  [spotify:artist:2yrbLiuBmc9j81lTX3XUuI]      False
# 1  [Michael Jackson]  [spotify:artist:3fMbdgg4jU18AjLCKBhRSm]      False
# 2  [Michael Jackson]  [spotify:artist:3fMbdgg4jU18AjLCKBhRSm]      False
# 3         [Rockwell]  [spotify:artist:3xs0LEzcPXtgNfMNcHzLIP]      False
# 4  [Michael Jackson]  [spotify:artist:3fMbdgg4jU18AjLCKBhRSm]      False
#
#    track_number  disc_number name_album  \
# 0             1            1     Scream
# ...

# %%
tracks_df.columns
# Out:
# Index(['name_track', 'duration_ms', 'explicit', 'artists_track',
#        'artists_track_uri', 'featuring', 'track_number', 'disc_number',
#        'name_album', 'artists_album', 'total_tracks', 'uri_track', 'uri_album',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature'],
#       dtype='object')

# %%
tracks_features_df = tracks_df[['name_track', 'danceability', 'energy', 'duration_ms', 'key', 'loudness',\
                                'mode', 'speechiness', 'acousticness', 'instrumentalness',\
                                'liveness', 'valence', 'tempo', 'time_signature', 'uri_track']]

# %%
tracks_features_df.drop('name_track', axis=1).drop('uri_track', axis=1)
# Out:
#      danceability  energy  duration_ms  key  loudness  mode  speechiness  \
# 0           0.731   0.851       343413    4    -4.085     0       0.1030
# 1           0.764   0.887       358053   11    -3.725     1       0.0738
# 2           0.806   0.816       253373    1    -2.767     1       0.0764
# 3           0.767   0.712       237760    1    -4.128     0       0.0324
# 4           0.734   0.801       280946    3    -4.525     1       0.0437
# ..            ...     ...          ...  ...       ...   ...          ...
# 295         0.403   0.759       172866    0   -10.920     1       0.0524
# 296         0.670   0.698       213893   10   -10.498     1       0.0295
# 297         0.473   0.742       170666    9   -11.202     0       0.1170
# 298         0.599   0.461       217973    8   -11.723     1       0.0244
# 299         0.357   0.249       158826    4   -14.270     1       0.0293
#
#      acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
import sklearn
import sklearn.mixture, sklearn.cluster
from sklearn.decomposition import PCA

# %%
gaussian_mixt = sklearn.mixture.GaussianMixture(n_components=239)
gaussian_mixt.fit(tracks_features_df.drop('uri_track', axis=1).drop('name_track', axis=1).drop_duplicates())
# Out:
# GaussianMixture(covariance_type='full', init_params='kmeans', max_iter=100,
#                 means_init=None, n_components=239, n_init=1,
#                 precisions_init=None, random_state=None, reg_covar=1e-06,
#                 tol=0.001, verbose=0, verbose_interval=10, warm_start=False,
#                 weights_init=None)

# %%
gaussian_mixt
# Out:
# GaussianMixture(covariance_type='full', init_params='kmeans', max_iter=100,
#                 means_init=None, n_components=239, n_init=1,
#                 precisions_init=None, random_state=None, reg_covar=1e-06,
#                 tol=0.001, verbose=0, verbose_interval=10, warm_start=False,
#                 weights_init=None)

# %%
data = tracks_features_df.drop('name_track', axis=1).drop('uri_track', axis=1)

model = sklearn.cluster.KMeans(n_clusters=17).fit(data)
tracks_df['label'] = model.predict(tracks_features_df.drop('name_track', axis=1).drop('uri_track', axis=1))
tracks_df.groupby('label').name_album.nunique()
# Out:
# label
# 0      9
# 1      1
# 2      6
# 3     10
# 4      2
# 5      3
# 6     12
# 7      6
# 8      6
# 9     14
# 10    10
# 11     8
# 12     2
# 13     7
# 14     8
# 15    11
# 16     4
# Name: name_album, dtype: int64

# %%
# Out:
#        name_track  danceability  energy  duration_ms  key  loudness  mode  \
# label
# 0              19            19      19           19   19        19    19
# 1              59            59      59           59   59        59    59
# 2              22            22      22           22   22        22    22
# 3              60            60      60           60   60        60    60
# 4               7             7       7            7    7         7     7
# 5              86            86      86           86   86        86    86
# 6              11            11      11           11   11        11    11
# 7              36            36      36           36   36        36    36
#
#        speechiness  acousticness  instrumentalness  liveness  valence  tempo  \
# label
# 0               19            19                19        19       19     19
# 1               59            59                59        59       59     59
# ...

# %%
ax = sns.scatterplot(x='altitude', y='CO2', hue='cluster_idx', style='cluster_idx', data=medianCO2_df, legend='full', palette='bright')
texts = [ax.text(row.altitude, row.CO2, row.LocationName, size='small', color='black') for _, row in medianCO2_df.iterrows()]
adjust_text(texts, arrowprops=dict(arrowstyle="-", color='k', lw=0.5))  # Attempt to improve the annotations, takes a while
ax.set_xlabel('Altitude of the station [m]')
ax.set_ylabel('CO_2 concentration [ppm]')
ax.set_title('Monthly median CO_2 concentration at a given altitude per station', fontsize=16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-67ba1dee53c3> in <module>
# ----> 1 tracks_features_df.scatter_plot('label')
#
# ~/Anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'scatter_plot'
