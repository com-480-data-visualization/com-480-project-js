# %%
import pandas as pd

lyrics_df = pd.read_csv("Lyrics_MichaelJackson_clean.csv")

lyrics_df.head()
# Out:
#    artist_id      artist_name featured_artists  featured_video  \
# 0        835  Michael Jackson               []            True
# 1        835  Michael Jackson               []           False
# 2        835  Michael Jackson               []            True
# 3        835  Michael Jackson               []            True
# 4        835  Michael Jackson               []           False
#
#                                        full_title  \
# 0                  Billie Jean by Michael Jackson
# 1              Smooth Criminal by Michael Jackson
# 2     They Don't Care About Us by Michael Jackson
# 3            Man in the Mirror by Michael Jackson
# 4  Wanna Be Startin' Somethin' by Michael Jackson
#
#                           header_image_thumbnail_url  \
# 0  https://images.genius.com/9ed845cfd193f95cf6bd...
# 1  https://images.genius.com/b9bfb36a041733c7bbf6...
# 2  https://images.genius.com/ed7f9a530d1417005450...
# 3  https://images.genius.com/b9bfb36a041733c7bbf6...
# ...

# %%
lyrics_df['full_title'].unique()
# Out:
# array(['Billie Jean by\xa0Michael\xa0Jackson',
#        'Smooth Criminal by\xa0Michael\xa0Jackson',
#        "They Don't Care About Us by\xa0Michael\xa0Jackson",
#        'Man in the Mirror by\xa0Michael\xa0Jackson',
#        "Wanna Be Startin' Somethin' by\xa0Michael\xa0Jackson",
#        'Thriller by\xa0Michael\xa0Jackson',
#        'Beat It by\xa0Michael\xa0Jackson',
#        'Human Nature by\xa0Michael\xa0Jackson',
#        'Dirty Diana by\xa0Michael\xa0Jackson',
#        'Bad by\xa0Michael\xa0Jackson',
#        'Heal the World by\xa0Michael\xa0Jackson',
#        'Black or White by\xa0Michael\xa0Jackson (Ft.\xa0L.T.B.)',
#        "Don't Stop 'Til You Get Enough by\xa0Michael\xa0Jackson",
#        'P.Y.T. (Pretty Young Thing) by\xa0Michael\xa0Jackson',
#        'Earth Song by\xa0Michael\xa0Jackson',
#        'Rock with You by\xa0Michael\xa0Jackson',
#        'The Way You Make Me Feel by\xa0Michael\xa0Jackson',
#        'You Are Not Alone by\xa0Michael\xa0Jackson',
# ...

# %%
for x in lyrics_df['title'].unique():
    if 'bad' in x.lower():
        print(x)
# Out:
# Bad
# 2 Bad
# Bad (Extended Video Remix)
# 2 Bad (Refugee Camp Mix)
# Bad (Remix By Afrojack - Dj Buddha Edit)
# Bad (Remix By Afrojack - Club Mix)
# Remember the Time / Bad (Immortal Version)
# Bad - live at wembley july 16, 1988

# %%
def get_lyrics(title):
    return lyrics_df[lyrics_df['title'] == title]['lyrics'].values[0]

print(get_lyrics('Billie Jean (1981 Home Demo)'))
# Out:
# More kick and stuff in the phones, I need
# More bottom and kick in the phones
#
# Tell me what did your daughter say, d-d-dong dong say?
# All of the time
# Alright, I see, alright
# All of the time
# Where we go, on the winds, in the wild
#
# She told me I was a lonely man and I felt sad
# She called my name then she said hello
# All them who died
# And I sit, in a cup, in a ride
#
# It seems that you, dun ber ber ber lee
# Har-har thin walla man
# Papa say, it doesn't care for what you do
# Careful what you do
# Buttercup a day Hey Hey Hey!
#
# ... Billie Jean is not my lover
# She's just a girl who that says that I am the one (do you know?)
# But the kid is not my son
# He He He Hey Hey Hey
# Billie Jean is not my lover
# She's just a girl who that says that I am the one (do you know?)
# But the kid is not my son
# She says I am the one, (Oh no!)
# But the kid is not my son

# %%
lyrics_df.shape
# Out:
# (378, 15)

# %%
len(lyrics_df['title'].unique())
# Out:
# 378

# %%
len(lyrics_df['lyrics'].unique())
# Out:
# 369

# %%
lyrics_df.shape
# Out:
# (378, 15)
